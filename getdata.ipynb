# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None,timeout = 60)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("erm2-nwe9", limit=100)
# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df.head()
# Out:
#   unique_key             created_date agency                      agency_name  \
# 0   50161504  2021-04-01T01:04:26.000   NYPD  New York City Police Department
# 1   50161411  2021-04-01T01:04:18.000   NYPD  New York City Police Department
# 2   50161612  2021-04-01T01:02:30.000   NYPD  New York City Police Department
# 3   50162580  2021-04-01T01:02:04.000    DOT     Department of Transportation
# 4   50157581  2021-04-01T01:02:01.000   NYPD  New York City Police Department
#
#             complaint_type                    descriptor  \
# 0          Illegal Parking               Blocked Hydrant
# 1          Illegal Parking  Commercial Overnight Parking
# 2  Noise - Street/Sidewalk              Loud Music/Party
# 3    Street Sign - Missing    St Name - Attached to Pole
# 4      Noise - Residential               Loud Television
#
#                 location_type incident_zip       incident_address  \
# 0             Street/Sidewalk        11103        32-45 47 STREET
# 1             Street/Sidewalk        10312       360 IONIA AVENUE
# 2             Street/Sidewalk        10468  245 WEST FORDHAM ROAD
# 3                      Street        11222       470 SCOTT AVENUE
# 4  Residential Building/House        11691  120 BEACH   19 STREET
#
#          street_name  ... :@computed_region_92fq_4b7q  \
# 0          47 STREET  ...                          33
# 1       IONIA AVENUE  ...                           9
# 2  WEST FORDHAM ROAD  ...                          29
# 3       SCOTT AVENUE  ...                          30
# 4  BEACH   19 STREET  ...                          47
#
#   :@computed_region_sbqj_enih closed_date resolution_description  \
# 0                          72         NaN                    NaN
# 1                          77         NaN                    NaN
# 2                          34         NaN                    NaN
# 3                          57         NaN                    NaN
# 4                          59         NaN                    NaN
#
#   resolution_action_updated_date bridge_highway_name bridge_highway_direction  \
# 0                            NaN                 NaN                      NaN
# 1                            NaN                 NaN                      NaN
# 2                            NaN                 NaN                      NaN
# 3                            NaN                 NaN                      NaN
# 4                            NaN                 NaN                      NaN
#
#   road_ramp bridge_highway_segment address_type
# 0       NaN                    NaN          NaN
# 1       NaN                    NaN          NaN
# 2       NaN                    NaN          NaN
# 3       NaN                    NaN          NaN
# 4       NaN                    NaN          NaN
#
# [5 rows x 41 columns]
